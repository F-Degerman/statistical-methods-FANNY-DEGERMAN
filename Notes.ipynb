# %% [markdown]
# STATISTIK & SANNOLIKHET

# %% [markdown]
# ├── 1. DATA & URVAL
#
# │   ├── Population
#
# │   ├── Stickprov
#
# │   │   ├── Stickprovsstorlek (n)
#
# │   │   ├── Oberoende observationer
#
# │   │   └── Rättvis skattning (unbiased)
#
# │   └── Ground truth

# %% [markdown]
# ├── 2. SANNOLIKHETSLÄRA
#
# │   ├── Slumpvariabel
#
# │   │   ├── Diskret
#
# │   │   └── Kontinuerlig
#
# │   ├── Utfallsrum
#
# │   ├── Händelse
#
# │   ├── Sannolikhetsbegrepp
#
# │   │   ├── Klassisk sannolikhet
#
# │   │   └── Relativ frekvens (frequentistisk)
#
# │   └── Oberoende / beroende händelser

# %% [markdown]
# ├── 3. KOMBINATORIK
#
# │   ├── Fakultet (n!)
#
# │   ├── Permutationer
#
# │   │   ├── Med ordning
#
# │   │   └── Utan återläggning
#
# │   ├── Kombinationer
#
# │   │   ├── Utan ordning
#
# │   │   └── Utan återläggning
#
# │   └── Uppräkning → sannolikhetsberäkning

# %% [markdown]
# ├── 4. FÖRDELNINGAR
#
# │   ├── Sannolikhetsfunktion (PMF / PDF)
#
# │   ├── Fördelningsfunktion (CDF)
#
# │   ├── Parametrar
#
# │   │   ├── μ (medel)
#
# │   │   └── σ² (varians)
#
# │   ├── Diskreta fördelningar
#
# │   │   ├── Binomial

# %% [markdown]
# kumulativa fördelningsfunktionen
# (Cumulative distribution function: F)
# - För diskreta variabler gäller:
#
# F(x) = P(X ≤ x)
#
# P(a ≤ X ≤ b) = F(b) − F(a − 1)

# %% [markdown]
# Exempeluppgift:
#
# 12 personer – sannolikhet att mellan 2 och 7 detekteras (70% chans att en upptäcks, p = .7)
#
# Här är:
# n = 12
# p = 0.7
#
# Vi söker:
# P(2 ≤ X ≤ 7)
#
# För att räkna ut med binom (scipy.stats) sätts k = 7 (värden för 0-7), n = 12 (totala antalet personer) och p = .7 (sannolikhet för ett lyckat försök). Sedan subtraherar vi värdena 0-1 (1,12,0.7) för att få ut P(2 ≤ X ≤ 7). Första exemplet är alla värden 0-7. Andra är spannet 2-7:

# %%
from scipy.stats import binom

# (k, n, p)

print(binom.cdf(7, 12, 0.7)) # Cumulative probability of getting at most 7 successes in 12 trials with a success probability of 0.7    
print(binom.cdf(7, 12, 0.7) - binom.cdf(1, 12, 0.7)) 
# Probability of getting exactly 7 successes in 12 trials with a success probability of 0.7
# Out:
# 0.27634453047000007
# 0.2763291186810001

# %% [markdown]
# │   │   ├── Negativ Binomial
#
# │   │   └── Geometrisk
#
# │   └── Kontinuerliga fördelningar
#
# │       ├── Normal
#
# │       ├── Standardnormal (Z)
#
# │       ├── Exponential
#
# │       ├── Gamma
#
# │       ├── t-fördelning
#
# │       └── F-fördelning

# %% [markdown]
# ├── 5. MOMENT & TEORETISKA MÅTT
#
# │   ├── Väntevärde E[X]
#
# │   ├── Varians Var(X)
#
# │   ├── Standardavvikelse σ
#
# │   └── Linjäritet hos väntevärde

# %% [markdown]
# ├── 6. BESKRIVANDE STATISTIK
#
# │   ├── Lägesmått
#
# │   │   ├── Medelvärde
#
# │   │   ├── Median
#
# │   │   └── Typvärde
#
# │   ├── Spridningsmått
#
# │   │   ├── Varians
#
# │   │   ├── Standardavvikelse
#
# │   │   └── Interkvartilavstånd
#
# │   └── Visualisering
#
# │       ├── Histogram
#
# │       ├── Kumulativt histogram
#
# │       ├── Boxplot
#
# │       └── Probplot

# %% [markdown]
# ├── 7. STATISTISK INFERENS
#
# │   ├── Konfidensintervall
#
# │   │   ├── Konfidensnivå (1 − α)
#
# │   │   ├── z-intervall
#
# │   │   └── t-intervall
#
# │   ├── Centrala gränsvärdessatsen
#
# │   └── De stora talens lag

# %% [markdown]
# ├── 8. HYPOTESPRÖVNING
#
# │   ├── Nollhypotes (H₀)
#
# │   ├── Alternativhypotes (H₁)
#
# │   ├── Teststatistika
#
# │   ├── p-värde
#
# │   ├── Ensidigt test
#
# │   └── Tvåsidigt test

# %% [markdown]
# ├── 9. GEMENSAMMA FÖRDELNINGAR
#
# │   ├── Gemensam fördelning
#
# │   ├── Marginalfördelning
#
# │   ├── Oberoende variabler
#
# │   └── Beroende variabler
#
# │       ├── Kovarians
#
# │       └── Korrelation

# %% [markdown]
# └── 10. REGRESSION
#
#     ├── Linjär regression
#
#     │   ├── Responsvariabel (Y)
#
#     │   ├── Prediktorer (X)
#
#     │   ├── Koefficienter (β)
#
#     │   └── Interaktionseffekter
#
#     ├── Minsta-kvadrat-metoden
#
#     ├── Felmått
#
#     │   ├── SSE
#
#     │   ├── MSE
#
#     │   └── RMSE
#
#     ├── Modellkvalitet
#
#     │   └── R² (förklaringsgrad)
#
#     └── Signifikans i regression
#
#         ├── F-test (modell)
#
#         └── t-test (parametrar)
