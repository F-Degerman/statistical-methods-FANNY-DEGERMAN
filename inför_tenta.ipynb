# %% [markdown]
# # Frågor Övningstenta 1 och 2

# %% [markdown]
# ## 1/1
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# a) Normalfördelning
# → Den som är S-formad och symmetrisk runt mitten.
#
# b) Geometrisk fördelning
# → Den som stiger snabbt i början och sedan planar ut (högerskev).

# %% [markdown]
# ## 2/1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
# Probplots
#
# a) Normalfördelning
# → Den som ligger rakt längs linjen.
#
# b) Diskret fördelning
# → Punkter i steg/kluster.

# %% [markdown]
# ## 1/2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **svar:**
#
# a) Fördelning?
# → Geometrisk fördelning
# Eftersom vi räknar antal försök tills första lyckande.
#
# b) När är mer än hälften > 1 försök?
# ![image.png](attachment:image.png)
#
# För geometrisk:
# ![image-2.png](attachment:image-2.png)
#
# Vill ha:
# ![image-3.png](attachment:image-3.png)
#
# Svar: Sannolikheten att minnet är ledigt måste vara mindre än 0.5.

# %% [markdown]
# ## 2/2

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Svar:**
#
# Robotar
#
# a) 3 oberoende moment →
# Binomialfördelning:
# ![image.png](attachment:image.png)
#
# b) medel:
# ![image-2.png](attachment:image-2.png)
#
# c) Upprepas tills 3 lyckanden →
# Negativ binomial

# %% [markdown]
# ## 1/3

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Svar:**
#
# Tolvsidig tärning
#
# Stickprov:
# [12,6,2,12,7,10]
#
# a) Från stickprov:
#
# 12 förekommer 2 gånger av 6
# ![image.png](attachment:image.png)
#
# b) Från population:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2/3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Sexsidig tärning
#
# Stickprov:
# [2,3,3,4,5,6,2,6]
#
# a)
# 2 förekommer 2 av 8
# ![image.png](attachment:image.png)
#
# b)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 1/4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Liten standardavvikelse jämfört med medel
#
# Om std ≪ medel →
# Stickproven ligger mycket nära medelvärdet →
# Liten spridning → stabil population.

# %% [markdown]
# ## 2/4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Rättvis skattare
#
# Om skattaren är rättvis:
# ![image.png](attachment:image.png)
# Stickprovsmedlet är i genomsnitt lika med populationsmedlet.

# %% [markdown]
# ## 1/5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Regression
# ![image.png](attachment:image.png)
#
# a) Lämplig konfidensnivå?
# R² = 0.68 → modellen förklarar 68%
# 95% är rimligt (α=0.05)
#
# c) Är Y=22 extremvärde när x₁=x₂=0?
#
# Prediktion:
# ![image-2.png](attachment:image-2.png)
#
# Avvikelse:
# ![image-3.png](attachment:image-3.png)
#
# Standardavvikelse = 4.5
# ![image-4.png](attachment:image-4.png)
#
# Drygt 2σ bort → ovanligt men inte extremt (3σ-regeln)
#
# Svar: Nej, inte extremvärde men ovanligt.

# %% [markdown]
# ## 2/5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Regression
#
# ![image.png](attachment:image.png)
#
# a) Lämplig konfidensnivå?
#
# R²=0.997 → extremt hög
# 99% rimligt (α=0.01)
#
# c) Extremvärde vid x₁=x₂=0?
#
# Prediktion:
# ![image-2.png](attachment:image-2.png)
# Givet värde = 2.605
#
# Skillnad:
# ![image-3.png](attachment:image-3.png)
#
# Inte extremt alls.

# %% [markdown]
# ## 1/6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Signifikanstest
#
# β₃ (interaktion) p=0.86
#
# a) Signifikant?
# Nej (p > 0.05)
#
# b) Alla parametrar lämpliga?
#
# β₁: p=0.4 → ej signifikant
# β₃: p=0.86 → ej signifikant
#
# Kan tas bort.

# %% [markdown]
# ## 2/6

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Svar:**
#
# Interaktion
#
# β₃ p = 1.86e−23
#
# a) Signifikant?
# Ja, extremt.
#
# b) Alla parametrar?
#
# β₂ p=0.6 → ej signifikant
# MEN interaktion signifikant →
# Hierarkiprincip → behåll huvudtermerna.

# %% [markdown]
# ## 1/7

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Svar:**
#
# Konfidensintervall
# a)
# n=81
# ![image.png](attachment:image.png)
#
# 95% CI:
# ![image-2.png](attachment:image-2.png)
#
# CI:
# ![image-3.png](attachment:image-3.png)
#
# b) Hur många procent > 10?
#
# 10 ligger nära övre gränsen → ca 2.5%

# %% [markdown]
# ## 2/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Konfidensintervall
#
# n=100
# ![image.png](attachment:image.png)
#
# 95% CI:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 1/8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Visa linearitet
# ![image.png](attachment:image.png)
#
# Dela upp summan:
# ![image-2.png](attachment:image-2.png)
#
# QED.

# %% [markdown]
# ## 2/8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Svar:**
#
# Linearitet i väntevärde
#
# Samma bevis som i tenta 1.
